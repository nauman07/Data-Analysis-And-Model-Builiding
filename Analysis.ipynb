# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

##Importing Data
data = pd.read_csv('diabetes.csv')

print(data.head())

print(data.isnull().sum())

for feature in data.columns:
    print(feature,':',len(data[feature].unique()))

discrete_features, continous_features =[] ,[]
for feature in data.columns:
    if feature=='Outcome':
        label=['Outcome']
    elif len(data[feature].unique())>= 10:
        continous_features.append(feature)
    else:
        discrete_features.append(feature)

print('Discrete:',discrete_features,'\n','Continous', continous_features)
    
correlation = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation , annot=True)
plt.show()

fig , ax =plt.subplots(len(discrete_features),2,figsize=(14,20))

for i in range(len(discrete_features)):
    sns.countplot(ax=ax[i,0],x=discrete_features[i],data=data)
    sns.countplot(ax=ax[i,1],x=discrete_features[i],hue='Outcome',data=data)
fig.tight_layout(pad=1)
plt.show()
sns.countplot(x='Outcome',data=data)
fig.tight_layout(pad=1)
plt.show()

for feature in continous_features:
    sns.kdeplot(data=data[feature],color='b', shade=True)
    plt.show()

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import chi2, SelectFromModel, SelectKBest
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score, RepeatedStratifiedKFold
from sklearn.svm import SVC
from imblearn.over_sampling import RandomOverSampler, SMOTE
import xgboost

best_features =  SelectKBest(chi2,k=8)
features_ranking = best_features.fit(data.drop(['Outcome'],axis=1),data['Outcome'])
ranking_dictionary={}
for i in range(len(features_ranking.scores_)):
    ranking_dictionary[data.columns[i]] = round(features_ranking.scores_[i],3)

asc_sort= sorted(ranking_dictionary.items(),key = lambda kv:(kv[1],kv[0]))

for i,j in asc_sort:
    print(i,':',j)

feature_model = SelectFromModel(Lasso(alpha=0.05, random_state=0))
feature_model.fit(data.drop(['Outcome'], axis=1), data['Outcome'])

mask = feature_model.get_support() 
for i in range(len(mask)):
    if not mask[i]:
        print(data.drop(['Outcome'], axis=1).columns[i])

X = data.drop(['Outcome'], axis=1)
y = data['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))


model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Random Forest is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

X = data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI','DiabetesPedigreeFunction','Age']]
y = data['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Random Forest is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

model = GradientBoostingClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Gradient Boost is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))


X = data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness']]
y = data['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

model = GradientBoostingClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Gradient Boost is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

X = data.drop(['Outcome'], axis=1)
y = data['Outcome']

oversample = RandomOverSampler(sampling_strategy='minority')
X_sampled, y_sampled = oversample.fit_resample(X, y)
print(Counter(y_sampled))

X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))


model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Random Forest is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

X = data[['Pregnancies', 'Glucose', 'BloodPressure']]
y = data['Outcome']

oversample = RandomOverSampler(sampling_strategy='minority')
X_sampled, y_sampled = oversample.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=2)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))


model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Random Forest is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))


model = GradientBoostingClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Gradient Boost is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

X = data.drop(['Outcome'], axis=1)
y = data['Outcome']

oversample = SMOTE(sampling_strategy='minority')
X_sampled, y_sampled = oversample.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X = data.drop(['Outcome'], axis=1)
y = data['Outcome']

oversample = SMOTE(sampling_strategy='minority')
X_sampled, y_sampled = oversample.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Random Forest is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

X = data[['Pregnancies', 'Glucose', 'BloodPressure']]
y = data['Outcome']

oversample = SMOTE(sampling_strategy='minority')
X_sampled, y_sampled = oversample.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=2)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Random Forest is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

model = GradientBoostingClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf = plot_confusion_matrix(model, X_test, y_test)
print ("The accuracy of Gradient Boost is : ", accuracy_score(y_test, y_pred)*100, "%")
print(classification_report(y_test, y_pred))

X = data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness']]
y = data['Outcome']

oversample = RandomOverSampler(sampling_strategy='minority')
X_sampled, y_sampled = oversample.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=2)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = GradientBoostingClassifier()
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=5, random_state=1)
score = cross_val_score(model, X_train, y_train, cv=cv)
print(score)
print(score.mean())

X = data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness']]
y = data['Outcome']

oversample = SMOTE(sampling_strategy='minority')
X_sampled, y_sampled = oversample.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=2)
print(X_train.shape, X_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = GradientBoostingClassifier()
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=5, random_state=1)
score = cross_val_score(model, X_train, y_train, cv=cv)
print(score)
print(score.mean())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# Pregnancies : 17
# Glucose : 136
# BloodPressure : 47
# SkinThickness : 51
# Insulin : 186
# BMI : 248
# DiabetesPedigreeFunction : 517
# Age : 52
# Outcome : 2
# Discrete: []
#  Continous ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
# DiabetesPedigreeFunction : 5.393
# BloodPressure : 17.605
# SkinThickness : 53.108
# Pregnancies : 111.52
# BMI : 127.669
# Age : 181.304
# Glucose : 1411.887
# Insulin : 2175.565
# DiabetesPedigreeFunction
# (614, 8) (154, 8)
# The accuracy of Logistic Regression is :  82.46753246753246 %
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       107
#            1       0.76      0.62      0.68        47
#
#     accuracy                           0.82       154
#    macro avg       0.80      0.77      0.78       154
# weighted avg       0.82      0.82      0.82       154
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Random Forest is :  81.16883116883116 %
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       107
#            1       0.71      0.64      0.67        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.76      0.77       154
# weighted avg       0.81      0.81      0.81       154
#
# (614, 8) (154, 8)
# The accuracy of Logistic Regression is :  76.62337662337663 %
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       109
#            1       0.63      0.49      0.55        45
#
#     accuracy                           0.77       154
#    macro avg       0.72      0.68      0.70       154
# weighted avg       0.75      0.77      0.76       154
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Random Forest is :  75.32467532467533 %
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       109
#            1       0.58      0.56      0.57        45
#
#     accuracy                           0.75       154
#    macro avg       0.70      0.70      0.70       154
# weighted avg       0.75      0.75      0.75       154
#
# The accuracy of Gradient Boost is :  73.37662337662337 %
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       109
#            1       0.54      0.56      0.55        45
#
#     accuracy                           0.73       154
#    macro avg       0.68      0.68      0.68       154
# weighted avg       0.74      0.73      0.73       154
#
# (614, 4) (154, 4)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Logistic Regression is :  75.97402597402598 %
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       109
#            1       0.62      0.44      0.52        45
#
#     accuracy                           0.76       154
#    macro avg       0.71      0.67      0.68       154
# weighted avg       0.75      0.76      0.75       154
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Gradient Boost is :  70.12987012987013 %
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79       109
#            1       0.49      0.42      0.45        45
#
#     accuracy                           0.70       154
#    macro avg       0.63      0.62      0.62       154
# weighted avg       0.69      0.70      0.69       154
#
# Counter({1: 500, 0: 500})
# (800, 8) (200, 8)
# The accuracy of Logistic Regression is :  80.0 %
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81       105
#            1       0.78      0.81      0.79        95
#
#     accuracy                           0.80       200
#    macro avg       0.80      0.80      0.80       200
# weighted avg       0.80      0.80      0.80       200
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Random Forest is :  88.0 %
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88       105
#            1       0.81      0.97      0.88        95
#
#     accuracy                           0.88       200
#    macro avg       0.89      0.88      0.88       200
# weighted avg       0.89      0.88      0.88       200
#
# (800, 3) (200, 3)
# The accuracy of Logistic Regression is :  72.5 %
#               precision    recall  f1-score   support
#
#            0       0.66      0.80      0.73        91
#            1       0.80      0.66      0.72       109
#
#     accuracy                           0.73       200
#    macro avg       0.73      0.73      0.72       200
# weighted avg       0.74      0.72      0.72       200
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Random Forest is :  82.0 %
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        91
#            1       0.85      0.82      0.83       109
#
#     accuracy                           0.82       200
#    macro avg       0.82      0.82      0.82       200
# weighted avg       0.82      0.82      0.82       200
#
# The accuracy of Gradient Boost is :  77.5 %
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77        91
#            1       0.83      0.74      0.78       109
#
#     accuracy                           0.78       200
#    macro avg       0.78      0.78      0.77       200
# weighted avg       0.78      0.78      0.78       200
#
# (800, 8) (200, 8)
# (800, 8) (200, 8)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Random Forest is :  85.5 %
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85       105
#            1       0.81      0.91      0.86        95
#
#     accuracy                           0.85       200
#    macro avg       0.86      0.86      0.85       200
# weighted avg       0.86      0.85      0.85       200
#
# (800, 3) (200, 3)
# The accuracy of Logistic Regression is :  69.0 %
#               precision    recall  f1-score   support
#
#            0       0.63      0.79      0.70        91
#            1       0.78      0.61      0.68       109
#
#     accuracy                           0.69       200
#    macro avg       0.70      0.70      0.69       200
# weighted avg       0.71      0.69      0.69       200
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\abc\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# The accuracy of Random Forest is :  71.0 %
#               precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70        91
#            1       0.76      0.69      0.72       109
#
#     accuracy                           0.71       200
#    macro avg       0.71      0.71      0.71       200
# weighted avg       0.71      0.71      0.71       200
#
# The accuracy of Gradient Boost is :  70.0 %
#               precision    recall  f1-score   support
#
#            0       0.64      0.79      0.71        91
#            1       0.78      0.62      0.69       109
#
#     accuracy                           0.70       200
#    macro avg       0.71      0.71      0.70       200
# weighted avg       0.72      0.70      0.70       200
#
# (800, 4) (200, 4)
# [0.75   0.825  0.8125 0.65   0.775  0.6875 0.75   0.75   0.8    0.75
#  0.7875 0.7    0.775  0.8375 0.7375 0.725  0.775  0.7375 0.775  0.7875
#  0.8375 0.6875 0.7875 0.7375 0.7125 0.7875 0.8125 0.7    0.7375 0.775
#  0.8125 0.8    0.7625 0.8625 0.75   0.75   0.7375 0.8    0.7125 0.7875
#  0.825  0.8    0.675  0.7625 0.75   0.725  0.7625 0.775  0.8125 0.75  ]
# 0.7635
# (800, 4) (200, 4)
# [0.725  0.7125 0.725  0.6375 0.725  0.675  0.7375 0.7875 0.775  0.8125
#  0.675  0.7    0.725  0.7625 0.725  0.7    0.825  0.725  0.7375 0.7625
#  0.825  0.6125 0.6875 0.775  0.7    0.775  0.7375 0.7375 0.7375 0.7
#  0.7375 0.7    0.7875 0.775  0.75   0.6375 0.725  0.7375 0.6375 0.75
#  0.6875 0.75   0.7125 0.6625 0.75   0.7375 0.8    0.7    0.725  0.7375]
# 0.72875
